# %% [markdown]
# # Import Necessary Libraries

# %%
import re
import nltk
import pymongo
import pandas as pd
import numpy as np
from pymongo.errors import ConnectionFailure
import string
import qalsadi.lemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import torch.optim as optim
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2024-05-25 22:44:17.861297: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-25 22:44:17.900367: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-25 22:44:17.900404: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-25 22:44:17.901425: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-25 22:44:17.907707: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-25 22:44:18.878518: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Connect with MongoDB to fetch Data from database : Lab4 , Collection: Sports

# %%
try:
    client = pymongo.MongoClient("mongodb://localhost:27017")
    database = client["Lab4"]
    collection = database['Sports']

    print('Connected to MongoDB successfully !')
    documents = collection.find()

except ConnectionFailure as e:
    print('Could not Connect to MongoDB:', e)
except Exception as e:
    print('An error occured:', e)
# Out:
# Connected to MongoDB successfully !

# %%
document = []
for doc in documents:
    Content = doc['Content']
    document.append(Content)

# %%
df = pd.DataFrame(document, columns=['Text'])

# %%
df
# Out:
#                                                   Text
# 0      \nلا شك أن كأس العالم في نسخته الأخيرة والتي...
# 1     احمد اوسار\nهناك سؤال وحديث تداولته بعض الجما...
# 2      \nخسارة مؤلمة تجرعها المنتخب الاسباني بطل أو...
# 3      \nلا شك أن انتقال الدولي المغربي المهدي بنعط...
# 4      \n1 -  على الرغم من بعض مظاهر الضعف و علامات...
# ..                                                 ...
# 165    \nتحدثت الصحف البريطانية عن احتمالية عودة ال...
# 166   خسر برشلونة في ملعبه بنتيجة قوية وكبيرة ضد ري...
# 167   أيام و يرحل مورينيو عن قلعة السانتياغو بيرناب...
# 168   انتهت مواجهة بايرن ميونخ وبرشلونة بمجزرة كامل...
# 169   مرة اخرى المغرب خارج تصفيات المونديال ، مرة ا...
#
# [170 rows x 1 columns]

# %% [markdown]
# ## Prepare our Dataset that we Add Score Column (Target) that Presents the relevance of each text

# %%
keywords = ['ميسي','فريق ','كأس', 'المغرب','مباراة', 'برشلونة'
            ,'البطولة','الوطنية','الفوز','اللعب','الهجومي'
            ,'الركلات','الأداء','الهجوم', 'والدفاع','الانتقال','المنتخب','الخسارة'
            ,'الأسود','الأطلس', 'ملعب','التغييرات','الجماهير','المغربية',
            'إسبانيا','المدرب', 'الوطني', 'كرة','القدم','مدريد','ريال']

# %% [markdown]
# ## Function to calculate relevalance score Based on TF-IDF

# %%
def calculate_relevance(texts, keywords):
    vectorizer = TfidfVectorizer(vocabulary=keywords)
    tfidf_matrix = vectorizer.fit_transform(texts)
    
    # Sum the TF-IDF scores for each document
    relevance_scores = tfidf_matrix.sum(axis=1)
    # Normalize the scores between 0 and 10
    max_score = relevance_scores.max()
    normalized_scores = (relevance_scores / max_score) * 10 if max_score > 0 else relevance_scores
    
    return normalized_scores

# %%
scores = calculate_relevance(df['Text'], keywords)

# %%
scores = np.asarray(scores).flatten()
df['Score'] = ["{:.1f}".format(score) for score in scores]

# %%
df['Score'].value_counts()
# Out:
# Score
# 3.3     12
# 4.7      8
# 0.0      8
# 6.5      8
# 6.6      8
# 6.3      8
# 7.1      6
# 5.7      6
# 6.8      6
# 7.8      6
# 5.9      4
# 5.8      4
# 7.6      4
# 9.0      4
# 7.7      4
# 8.0      4
# 5.6      4
# 5.3      4
# 5.4      4
# 8.1      4
# 8.6      4
# 7.5      4
# 5.2      4
# 7.0      4
# 8.2      4
# 9.1      2
# 5.1      2
# 4.9      2
# 8.8      2
# 4.6      2
# 7.2      2
# 7.4      2
# 7.3      2
# 4.5      2
# 4.3      2
# 10.0     2
# 6.7      2
# 8.4      2
# 7.9      2
# 3.8      2
# 5.0      2
# 6.4      2
# Name: count, dtype: int64

# %%
df
# Out:
#                                                   Text Score
# 0      \nلا شك أن كأس العالم في نسخته الأخيرة والتي...   8.0
# 1     احمد اوسار\nهناك سؤال وحديث تداولته بعض الجما...   4.7
# 2      \nخسارة مؤلمة تجرعها المنتخب الاسباني بطل أو...   7.7
# 3      \nلا شك أن انتقال الدولي المغربي المهدي بنعط...   7.6
# 4      \n1 -  على الرغم من بعض مظاهر الضعف و علامات...   9.0
# ..                                                 ...   ...
# 165    \nتحدثت الصحف البريطانية عن احتمالية عودة ال...   6.4
# 166   خسر برشلونة في ملعبه بنتيجة قوية وكبيرة ضد ري...   8.4
# 167   أيام و يرحل مورينيو عن قلعة السانتياغو بيرناب...   6.7
# 168   انتهت مواجهة بايرن ميونخ وبرشلونة بمجزرة كامل...   6.3
# 169   مرة اخرى المغرب خارج تصفيات المونديال ، مرة ا...   3.3
#
# [170 rows x 2 columns]

# %% [markdown]
# ## Function contain techniques to clean text and Normalisation and Discretization

# %%
def CleanNormalize(text):

    #RegEx Patterns
    p_mention = r'\@[\_0-9a-zA-Z]+\:?'
    p_url = r'https?://[A-Za-z0-9./]+'
    p_others = r'[a-zA-Z0-9]+'

    
    if(not isinstance(text, str)):
        return ''
    
    #Cleaning
    text = re.sub(p_mention, 'تنويهحساب', text)  #check mentions
    text = re.sub(p_url, 'وجودرابط', text)   #check URLs
        
    text = re.sub('['+string.punctuation+']', ' ', text)  # Remove punctuation    
    text = re.sub(p_others, '', text)  #remove english chars and numbers
    
    #Normalization
    text = re.sub("[إأٱآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("ة", "ه", text)
    
    noise = re.compile(""" ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)
    text = re.sub(noise, '', text)
    
    text = re.sub(r'(.)\1+', r'\1\1', text) #repeated chars
    
    #Removing linebreaks and extra whitespaces
    text = text.replace('\n', ' ').replace('\r', ' ')  
    text = re.sub('\W', ' ', text)
    text = re.sub(' +', ' ', text)
    
    return text.strip()

# %%
df['Text'] = df['Text'].apply(lambda x: CleanNormalize(x))

# %%
df
# Out:
#                                                   Text Score
# 0    لا شك ان كاس العالم في نسخته الاخيره والتي اقي...   8.0
# 1    احمد اوسار هناك سءال وحديث تداولته بعض الجماهي...   4.7
# 2    خساره مءلمه تجرعها المنتخب الاسباني بطل اوروبا...   7.7
# 3    لا شك ان انتقال الدولي المغربي المهدي بنعطيه ا...   7.6
# 4    علي الرغم من بعض مظاهر الضعف و علامات الخلل ال...   9.0
# ..                                                 ...   ...
# 165  تحدثت الصحف البريطانيه عن احتماليه عوده المدير...   6.4
# 166  خسر برشلونه في ملعبه بنتيجه قويه وكبيره ضد ريا...   8.4
# 167  ايام و يرحل مورينيو عن قلعه السانتياغو بيرنابي...   6.7
# 168  انتهت مواجهه بايرن ميونخ وبرشلونه بمجزره كامله...   6.3
# 169  مره اخري المغرب خارج تصفيات المونديال مره اخري...   3.3
#
# [170 rows x 2 columns]

# %% [markdown]
# # preprocessing NLP pipeline

# %%
ar_stop_list = open("arabic_stopwords.txt", encoding="utf-8")
stop_words = ar_stop_list.read().split('\n')
lemmatizer = qalsadi.lemmatizer.Lemmatizer()
def preprocessing_data(data):
    # Tokenization
    data = word_tokenize(data)
    # Remove Stop words
    data = [kalima for kalima in data if kalima not in stop_words]
    # Lemmatization
    data = [lemmatizer.lemmatize(kalima) for kalima in data]
    return data

# %%
df['Text'] = df['Text'].apply(lambda x: preprocessing_data(x))

# %%
df
# Out:
#                                                   Text Score
# 0    [شك, كاسي, عالم, نسخة, الاخيره, اقيمت, الاراضي...   8.0
# 1    [حمد, اوسار, سءال, حديث, تداول, جماهير, القنيط...   4.7
# 2    [خسار, مءلمه, تجرع, منتخب, الاسباني, بطل, اورو...   7.7
# 3    [شك, انتقال, دولي, مغرب, مهد, بنعطيه, صفوف, نا...   7.6
# 4    [رغم, مظاهر, ضعف, علام, خلل, اعترى, الانجاز, ك...   9.0
# ..                                                 ...   ...
# 165  [تحدث, صحف, البريطانيه, احتمال, عود, مدير, فن,...   6.4
# 166  [خسر, برشلونه, ملعب, بنتيجه, قوة, كبير, مدريد,...   8.4
# 167  [رحل, مورينيو, قلع, سانتياغو, بيرنابيو, سدل, س...   6.7
# 168  [انتهى, مواجه, بايرن, ميونخ, وبرشلونه, مجزر, ك...   6.3
# 169  [مر, اخري, مغرب, تصفية, مونديال, مر, اخري, طمو...   3.3
#
# [170 rows x 2 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Tokenization:
# Tokenization is the process of breaking down a piece of text into smaller units, such as words or subwords. Each token typically represents a meaningful unit of the text.
#
# #### Example:
# - "hello world" becomes [1, 2]
# - "how are you" becomes [3, 4, 5]
# - "I am fine" becomes [6, 7, 8]
#
# ### Padding:
# Padding ensures that all sequences have the same length, which is necessary for batch processing in neural networks.
#
# #### Example:
# - After tokenization, we find the maximum length of the sequences. In this case, it's 3.
# - We pad the sequences to have the same length by adding zeros to the end:
#   - [1, 2, 0]
#   - [3, 4, 5]
#   - [6, 7, 8]

# %%
texts_flat = [' '.join(tokens) for tokens in df['Text']]
# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts_flat)
sequences = tokenizer.texts_to_sequences(texts_flat)
print('Tokenized sequences:' ,sequences)
# Out:
# Tokenized sequences: [[263, 15, 12, 3326, 202, 2191, 2192, 484, 2193, 14, 3327, 126, 35, 2194, 882, 116, 27, 2195, 264, 1277, 561, 18, 14, 99, 281, 3328, 126, 36, 1278, 883, 7, 883, 2196, 235, 60, 61, 100, 2197, 392, 203, 34, 3329, 1046, 309, 1601, 24, 265, 648, 3330, 393, 53, 3331, 649, 310, 2198, 27, 3332, 758, 149, 1602, 3333, 3334, 14, 485, 759, 884, 7, 2199, 15, 12, 2200, 3335, 343, 12, 884, 2201, 1279, 3336, 10, 1603, 760, 117, 1280, 3337, 4, 3338, 2202, 761, 1603, 22, 3339, 2203, 166, 885, 1278, 7, 1604, 311, 2, 486, 1281, 344, 3340, 2204, 2205, 650, 3341, 886, 651, 3342, 101, 266, 267, 2, 219, 149, 3343, 1047, 394, 1048, 3344, 4, 1605, 487, 395, 13, 3345, 887, 150, 2206, 562, 3346, 7, 1606, 3347, 167, 2207, 652, 888, 345, 6, 204, 345, 24, 486, 653, 1607, 220, 168, 7, 486, 3348, 183, 36, 1608, 24, 3349, 346, 889, 268, 2208, 1609, 3350, 563, 36, 2209, 564, 1610, 1611, 1612, 93, 1613, 2210, 1614, 347, 1615, 265, 3351, 883, 565, 4, 36, 14, 66, 2211, 654, 135, 46, 3352, 3353, 102, 36, 135, 65, 6, 4, 3, 184, 3354, 127, 205, 488, 3355, 890, 3356, 890, 3357, 3, 1616, 3358, 891, 3359, 2212, 762, 135, 489, 185, 3360, 3361, 2213, 1049, 136, 183, 883, 3362, 67, 3363, 3364, 3365, 1050, 2213, 65, 128, 102, 1617, 884, 486, 282, 1618, 203, 1619, 236, 1282, 1619, 7, 1620, 84, 3366, 53, 7, 892, 3367, 118, 36, 220, 128, 486, 2214, 49, 3368, 111, 12, 14, 486, 151, 1051, 1601, 24], [348, 3369, 763, 764, 1621, 63, 3370, 349, 66, 1622, 350, 1623, 68, 2215, 1624, 765, 351, 3371, 490, 11, 2216, 24, 50, 1283, 221, 137, 269, 11, 2217, 1625, 11, 1626, 167, 283, 893, 1627, 438, 2218, 3372, 885, 44, 73, 1, 655, 78, 30, 2219, 1279, 3373, 2, 2202, 1284, 94, 117, 206, 68, 1, 3374, 3375, 396, 50, 184, 566, 567, 284, 13, 568, 2220, 129, 3376, 3377, 3378, 50, 312, 3379, 45, 2221, 27, 438, 569, 568, 206, 2222, 285, 766, 10, 1285, 270, 1628, 1629, 656, 269, 1, 1622, 350, 1623, 2223, 397, 1286, 1052, 2217, 766, 2219, 3380, 2224, 1287, 1288, 50, 137, 439, 207, 3, 237, 1053, 2, 3381, 1289, 570, 2225, 50, 3382, 238, 138, 206, 1, 1, 1283, 396, 568, 2222, 222, 352, 767, 37, 1630, 313, 1290, 768, 568, 206, 568, 491, 2226, 1291, 3383, 73, 11, 152, 492, 1631, 3384, 894, 2227, 2, 1054, 16, 3385, 50, 769, 50, 1283, 1292, 239, 2228, 2229, 10, 66, 1632, 349, 657, 3386, 50, 271, 2230, 3387, 1290, 45, 765, 93, 3388, 78, 1050, 571, 3389, 1633, 50, 765, 314, 1293, 1634, 3390, 3391, 314, 1050, 150, 30, 569, 1635, 895, 398, 491, 3392, 1055, 1636, 1625, 50], [240, 3393, 770, 7, 315, 151, 286, 399, 7, 3394, 1056, 572, 272, 573, 79, 493, 286, 3395, 2231, 440, 51, 223, 1637, 34, 51, 30, 658, 266, 649, 139, 2232, 51, 241, 153, 3396, 1638, 3397, 47, 2233, 140, 574, 111, 266, 2234, 266, 283, 186, 2235, 35, 659, 3398, 3399, 2236, 896, 223, 2237, 84, 3400, 3401, 3402, 154, 1290, 2238, 651, 3403, 3404, 1057, 69, 2239, 2240, 400, 569, 237, 494, 3405, 771, 1639, 3406, 3407, 3408, 3409, 70, 80, 1640, 85, 2241, 1641, 141, 3410, 287, 2242, 236, 1640, 352, 240, 284, 11, 28, 62, 86, 897, 2235, 58, 155, 10, 310, 1294, 42, 3411, 772, 575, 3412, 3413, 16, 316, 168, 149, 3414, 3415, 1642, 2243, 87, 397, 2244, 651, 660, 138, 16, 895, 1293, 223, 1295, 13, 208, 42, 3416, 1643, 3417, 2245, 203, 2246, 3418, 392, 1643, 495, 223, 1296, 1295, 281, 9, 401, 3419, 13, 2247, 9, 58, 2241, 70, 2248, 2249, 3420, 441, 773, 1058, 3421, 2250, 62, 774, 3422, 3423, 12, 85, 3424, 61, 126, 119, 22, 651, 397, 1644, 283, 88, 661, 1644, 127, 1057, 2251, 223, 897, 775, 653, 1645, 1059, 3425, 776, 350, 31, 15, 12, 79, 493, 286, 496, 135, 1297, 9, 316, 495, 223, 1295, 103, 156, 3426, 25, 3427, 400, 898, 2252, 440, 1298, 2253, 2254, 61, 3428, 1646, 899, 1647, 1060, 397, 1061, 2244, 3429, 46, 150, 317, 3430, 763, 141, 662, 3431, 137, 442, 89, 1062, 1063, 397, 223, 3432, 15, 12, 318, 3433, 88, 3434, 3435, 65, 440, 3436, 497, 19, 899, 319, 498, 223, 499, 441, 54, 138, 773, 1058, 103, 223, 187, 1648, 209, 7, 1, 74, 777, 40, 773, 1058, 663, 778, 202, 3437, 1649, 223, 288, 2255, 1650, 169, 761, 46, 150, 224, 402, 266, 130, 30, 90 ...

# %%
# Padding
max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')
print('Padded sequences:', padded_sequences)
# Out:
# Padded sequences: [[ 263   15   12 ...    0    0    0]
#  [ 348 3369  763 ...    0    0    0]
#  [ 240 3393  770 ...    0    0    0]
#  ...
#  [ 294   42 1849 ...    0    0    0]
#  [ 210  238  170 ...    0    0    0]
#  [  46  150    8 ...    0    0    0]]

# %%
target = np.array(df['Score'], dtype=np.float32)

# %% [markdown]
# # Splitting the dataset
#
#
# We need to split the dataset into training and testing sets. We will use the first 80% of the dataset as the training set, another 20% as the testing

# %%
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, target, test_size = 0.2, random_state=42)

# %% [markdown]
# ## Stock The Dataset

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
class ArabicDataset(Dataset):
    def __init__(self, sequences, labels):
        self.sequences = sequences
        self.labels = labels

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        sequence = torch.tensor(self.sequences[idx], dtype=torch.long)
        label = torch.tensor(self.labels[idx], dtype=torch.float32)
        return sequence, label

# %% [markdown]
# ## Create Loader

# %%
train_dataset = ArabicDataset(X_train, y_train)
test_dataset = ArabicDataset(X_test, y_test)

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# %% [markdown]
# # Define the Models Architecture

# %% [markdown]
# ## Define RNN

# %%
class TextRNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super(TextRNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, num_layers=n_layers, 
                          bidirectional=bidirectional, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        embedded = self.embedding(text)
        output, hidden = self.rnn(embedded)
        if self.rnn.bidirectional:
            hidden = self.dropout(torch.cat((hidden[-2, :, :], hidden[-1, :, :]), dim=1))
        else:
            hidden = self.dropout(hidden[-1, :, :])
        return self.fc(hidden)

# %% [markdown]
# ## Define GRU

# %%
class TextGRU(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super(TextGRU, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.GRU(embedding_dim, hidden_dim, num_layers=n_layers, 
                          bidirectional=bidirectional, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        embedded = self.embedding(text)
        output, hidden = self.rnn(embedded)
        if self.rnn.bidirectional:
            hidden = self.dropout(torch.cat((hidden[-2, :, :], hidden[-1, :, :]), dim=1))
        else:
            hidden = self.dropout(hidden[-1, :, :])
        return self.fc(hidden)

# %% [markdown]
# ## Define LSTM

# %%
class TextLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super(TextLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=n_layers, 
                           bidirectional=bidirectional, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        embedded = self.embedding(text)
        output, (hidden, cell) = self.rnn(embedded)
        if self.rnn.bidirectional:
            hidden = self.dropout(torch.cat((hidden[-2, :, :], hidden[-1, :, :]), dim=1))
        else:
            hidden = self.dropout(hidden[-1, :, :])
        return self.fc(hidden)

# %% [markdown]
# # tuning hyper-parameters

# %%
VOCAB_SIZE = len(tokenizer.word_index) + 1
EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 1
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.5

# %%
model = TextLSTM(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT)

# Define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# %% [markdown]
# # Train the model

# %%
def train(model, iterator, optimizer, criterion, device):
    model.train()
    epoch_loss = 0
    predictions = []
    labels = []
    for text, label in iterator:
        optimizer.zero_grad()
        text, label = text.to(device), label.to(device)
        output = model(text).squeeze(1)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        predictions.extend(output.detach().cpu().numpy())
        labels.extend(label.detach().cpu().numpy())
    return epoch_loss / len(iterator), predictions, labels

def evaluate(model, iterator, criterion, device):
    model.eval()
    epoch_loss = 0
    predictions = []
    labels = []
    with torch.no_grad():
        for text, label in iterator:
            text, label = text.to(device), label.to(device)
            output = model(text).squeeze(1)
            loss = criterion(output, label)
            epoch_loss += loss.item()
            predictions.extend(output.detach().cpu().numpy())
            labels.extend(label.detach().cpu().numpy())
    return epoch_loss / len(iterator), predictions, labels

# %%
def calculate_regression_metrics(predictions, labels):
    mse = mean_squared_error(labels, predictions)
    mae = mean_absolute_error(labels, predictions)
    r2 = r2_score(labels, predictions)
    return mse, mae, r2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training loop

# %%
N_EPOCHS = 35

# %%
def train_and_evaluate(models, loaders, optimizer, criterion, device, epochs):
    for model_class in models:
        model = model_class(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT).to(device)
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        print('----------------------------------------------------')
        print('----------------------------------------------------')
        print(f"\nTraining {model_class.__name__}...")
        for epoch in range(epochs):
            train_loss, train_predictions, train_labels = train(model, loaders['train'], optimizer, criterion, device)
            test_loss, test_predictions, test_labels = evaluate(model, loaders['test'], criterion, device)
            train_mse, train_mae, train_r2 = calculate_regression_metrics(train_predictions, train_labels)
            test_mse, test_mae, test_r2 = calculate_regression_metrics(test_predictions, test_labels)
            print(f'------------------------------   Epoch: {epoch+1:02} --------------------------------')
            print(f'Train Loss: {train_loss:.3f}, Test Loss: {test_loss:.3f}')
            print(f'Train MSE: {train_mse:.3f}, Test MSE: {test_mse:.3f}')
            print(f'Train MAE: {train_mae:.3f}, Test MAE: {test_mae:.3f}')
            print(f'Train R²: {train_r2:.3f}, Test R²: {test_r2:.3f}')
            print('----------------------------------------------------')

# %%
models = [TextRNN, TextGRU, TextLSTM]
loaders = {'train': train_loader, 'test': test_loader}

train_and_evaluate(models, loaders, optimizer, criterion, device, N_EPOCHS)
# Out:
# ----------------------------------------------------
# ----------------------------------------------------
#
# Training TextRNN...
# ------------------------------   Epoch: 01 --------------------------------
# Train Loss: 14.234, Test Loss: 5.773
# Train MSE: 14.344, Test MSE: 5.786
# Train MAE: 3.041, Test MAE: 1.821
# Train R²: -2.346, Test R²: -0.350
# ----------------------------------------------------
# ------------------------------   Epoch: 02 --------------------------------
# Train Loss: 4.216, Test Loss: 2.064
# Train MSE: 4.253, Test MSE: 2.164
# Train MAE: 1.524, Test MAE: 1.151
# Train R²: 0.008, Test R²: 0.495
# ----------------------------------------------------
# ------------------------------   Epoch: 03 --------------------------------
# Train Loss: 2.393, Test Loss: 1.084
# Train MSE: 2.470, Test MSE: 1.035
# Train MAE: 1.253, Test MAE: 0.769
# Train R²: 0.424, Test R²: 0.759
# ----------------------------------------------------
# ------------------------------   Epoch: 04 --------------------------------
# Train Loss: 1.289, Test Loss: 0.623
# Train MSE: 1.308, Test MSE: 0.628
# Train MAE: 0.866, Test MAE: 0.583
# Train R²: 0.695, Test R²: 0.853
# ----------------------------------------------------
# ------------------------------   Epoch: 05 --------------------------------
# Train Loss: 0.808, Test Loss: 0.397
# Train MSE: 0.816, Test MSE: 0.392
# Train MAE: 0.684, Test MAE: 0.479
# Train R²: 0.810, Test R²: 0.908
# ----------------------------------------------------
# ------------------------------   Epoch: 06 --------------------------------
# Train Loss: 0.761, Test Loss: 0.339
# Train MSE: 0.775, Test MSE: 0.346
# Train MAE: 0.670, Test MAE: 0.453
# Train R²: 0.819, Test R²: 0.919
# ----------------------------------------------------
# ------------------------------   Epoch: 07 --------------------------------
# Train Loss: 0.594, Test Loss: 0.370
# Train MSE: 0.624, Test MSE: 0.373
# Train MAE: 0.596, Test MAE: 0.487
# Train R²: 0.854, Test R²: 0.913
# ----------------------------------------------------
# ------------------------------   Epoch: 08 --------------------------------
# Train Loss: 0.624, Test Loss: 0.280
# Train MSE: 0.650, Test MSE: 0.279
# Train MAE: 0.664, Test MAE: 0.406
# Train R²: 0.848, Test R²: 0.935
# ----------------------------------------------------
# ------------------------------   Epoch: 09 --------------------------------
# Train Loss: 0.603, Test Loss: 0.248
# Train MSE: 0.610, Test MSE: 0.255
# Train MAE: 0.592, Test MAE: 0.385
# Train R²: 0.858, Test R²: 0.941
# ----------------------------------------------------
# ------------------------------   Epoch: 10 --------------------------------
# Train Loss: 0.611, Test Loss: 0.306
# Train MSE: 0.585, Test MSE: 0.295
# Train MAE: 0.608, Test MAE: 0.424
# Train R²: 0.864, Test R²: 0.931
# ----------------------------------------------------
# ------------------------------   Epoch: 11 --------------------------------
# Train Loss: 0.529, Test Loss: 0.215
# Train MSE: 0.534, Test MSE: 0.212
# Train MAE: 0.583, Test MAE: 0.351
# Train R²: 0.876, Test R²: 0.951
# ----------------------------------------------------
# ------------------------------   Epoch: 12 --------------------------------
# Train Loss: 0.520, Test Loss: 0.330
# Train MSE: 0.534, Test MSE: 0.331
# Train MAE: 0.595, Test MAE: 0.465
# Train R²: 0.876, Test R²: 0.923
# ----------------------------------------------------
# ------------------------------   Epoch: 13 --------------------------------
# Train Loss: 0.450, Test Loss: 0.187
# Train MSE: 0.454, Test MSE: 0.187
# Train MAE: 0.531, Test MAE: 0.336
# Train R²: 0.894, Test R²: 0.956
# ----------------------------------------------------
# ------------------------------   Epoch: 14 --------------------------------
# Train Loss: 0.540, Test Loss: 0.189
# Train MSE: 0.532, Test MSE: 0.190
# Train MAE: 0.574, Test MAE: 0.335
# Train R²: 0.876, Test R²: 0.956
# ----------------------------------------------------
# ------------------------------   Epoch: 15 --------------------------------
# Train Loss: 0.331, Test Loss: 0.295
# Train MSE: 0.332, Test MSE: 0.291
# Train MAE: 0.448, Test MAE: 0.425
# Train R²: 0.923, Test R²: 0.932
# ----------------------------------------------------
# ------------------------------   Epoch: 16 --------------------------------
# Train Loss: 0.542, Test Loss: 0.180
# Train MSE: 0.556, Test MSE: 0.176
# Train MAE: 0.569, Test MAE: 0.327
# Train R²: 0.870, Test R²: 0.959
# ----------------------------------------------------
# ------------------------------   Epoch: 17 --------------------------------
# Train Loss: 0.415, Test Loss: 0.313
# Train MSE: 0.407, Test MSE: 0.302
# Train MAE: 0.505, Test MAE: 0.449
# Train R²: 0.905, Test R²: 0.930
# ----------------------------------------------------
# ------------------------------   Epoch: 18 --------------------------------
# Train Loss: 0.414, Test Loss: 0.241
# Train MSE: 0.418, Test MSE: 0.242
# Train MAE: 0.524, Test MAE: 0.390
# Train R²: 0.903, Test R²: 0.944
# ----------------------------------------------------
# ------------------------------   Epoch: 19 --------------------------------
# Train Loss: 0.451, Test Loss: 0.223
# Train MSE: 0.455, Test MSE: 0.227
# Train MAE: 0.538, Test MAE: 0.391
# Train R²: 0.894, Test R²: 0.947
# ----------------------------------------------------
# ------------------------------   Epoch: 20 --------------------------------
# Train Loss: 0.352, Test Loss: 0.186
# Train MSE: 0.343, Test MSE: 0.190
# Train MAE: 0.482, Test MAE: 0.363
# Train R²: 0.920, Test R²: 0.956
# ----------------------------------------------------
# ------------------------------   Epoch: 21 --------------------------------
# Train Loss: 0.418, Test Loss: 0.244
# Train MSE: 0.430, Test MSE: 0.242
# Train MAE: 0.522, Test MAE: 0.411
# Train R²: 0.900, Test R²: 0.944
# ----------------------------------------------------
# ------------------------------   Epoch: 22 --------------------------------
# Train Loss: 0.445, Test Loss: 0.145
# Train MSE: 0.449, Test MSE: 0.145
# Train MAE: 0.522, Test MAE: 0.287
# Train R²: 0.895, Test R²: 0.966
# ----------------------------------------------------
# ------------------------------   Epoch: 23 --------------------------------
# Train Loss: 0.429, Test Loss: 0.179
# Train MSE: 0.442, Test MSE: 0.184
# Train MAE: 0.538, Test MAE: 0.331
# Train R²: 0.897, Test R²: 0.957
# ----------------------------------------------------
# ------------------------------   Epoch: 24 --------------------------------
# Train Loss: 0.338, Test Loss: 0.129
# Train MSE: 0.343, Test MSE: 0.127
# Train MAE: 0.476, Test MAE: 0.286
# Train R²: 0.920, Test R²: 0.970
# ----------------------------------------------------
# ------------------------------   Epoch: 25 --------------------------------
# Train Loss: 0.448, Test Loss: 0.200
# Train MSE: 0.426, Test MSE: 0.197
# Train MAE: 0.531, Test MAE: 0.346
# Train R²: 0.901, Test R²: 0.954
# ----------------------------------------------------
# ------------------------------   Epoch: 26 --------------------------------
# Train Loss: 0.411, Test Loss: 0.122
# Train MSE: 0.406, Test MSE: 0.126
# Train MAE: 0.514, Test MAE: 0.266
# Train R²: 0.905, Test R²: 0.971
# ----------------------------------------------------
# ------------------------------   Epoch: 27 --------------------------------
# Train Loss: 0.463, Test Loss: 0.215
# Train MSE: 0.454, Test MSE: 0.207
# Train MAE: 0.537, Test MAE: 0.353
# Train R²: 0.894, Test R²: 0.952
# ----------------------------------------------------
# ------------------------------   Epoch: 28 --------------------------------
# Train Loss: 0.330, Test Loss: 0.093
# Train MSE: 0.332, Test MSE: 0.094
# Train MAE: 0.462, Test MAE: 0.239
# Train R²: 0.923, Test R²: 0.978
# ----------------------------------------------------
# ------------------------------   Epoch: 29 --------------------------------
# Train Loss: 0.484, Test Loss: 0.103
# Train MSE: 0.478, Test MSE: 0.104
# Train MAE: 0.555, Test MAE: 0.246
# Train R²: 0.888, Test R²: 0.976
# ----------------------------------------------------
# ------------------------------   Epoch: 30 --------------------------------
# Train Loss: 0.348, Test Loss: 0.132
# Train MSE: 0.336, Test MSE: 0.133
# Train MAE: 0.456, Test MAE: 0.251
# Train R²: 0.922, Test R²: 0.969
# ----------------------------------------------------
# ------------------------------   Epoch: 31 --------------------------------
# Train Loss: 0.465, Test Loss: 0.163
# Train MSE: 0.470, Test MSE: 0.163
# Train MAE: 0.535, Test MAE: 0.297
# Train R²: 0.890, Test R²: 0.962
# ----------------------------------------------------
# ------------------------------   Epoch: 32 --------------------------------
# Train Loss: 0.284, Test Loss: 0.141
# Train MSE: 0.274, Test MSE: 0.132
# Train MAE: 0.411, Test MAE: 0.287
# Train R²: 0.936, Test R²: 0.969
# ----------------------------------------------------
# ------------------------------   Epoch: 33 --------------------------------
# Train Loss: 0.351, Test Loss: 0.125
# Train MSE: 0.354, Test MSE: 0.123
# Train MAE: 0.449, Test MAE: 0.247
# Train R²: 0.917, Test R²: 0.971
# ----------------------------------------------------
# ------------------------------   Epoch: 34 --------------------------------
# Train Loss: 0.388, Test Loss: 0.101
# Train MSE: 0.390, Test MSE: 0.098
# Train MAE: 0.488, Test MAE: 0.240
# Train R²: 0.909, Test R²: 0.977
# ----------------------------------------------------
# ------------------------------   Epoch: 35 --------------------------------
# Train Loss: 0.357, Test Loss: 0.168
# Train MSE: 0.353, Test MSE: 0.162
# Train MAE: 0.497, Test MAE: 0.305
# Train R²: 0.918, Test R²: 0.962
# ----------------------------------------------------
# ----------------------------------------------------
# ----------------------------------------------------
#
# Training TextGRU...
# ------------------------------   Epoch: 01 --------------------------------
# Train Loss: 13.840, Test Loss: 4.942
# Train MSE: 14.382, Test MSE: 4.769
# Train MAE: 2.993, Test MAE: 1.579
# Train R²: -2.355, Test R²: -0.112
# ----------------------------------------------------
# ------------------------------   Epoch: 02 --------------------------------
# Train Loss: 4.135, Test Loss: 2.878
# Train MSE: 4.333, Test MSE: 2.920
# Train MAE: 1.505, Test MAE: 1.330
# Train R²: -0.011, Test R²: 0.319
# ----------------------------------------------------
# ------------------------------   Epoch: 03 --------------------------------
# Train Loss: 2.990, Test Loss: 1.759
# Train MSE: 3.028, Test MSE: 1.769
# Train MAE: 1.382, Test MAE: 1.055
# Train R²: 0.294, Test R²: 0.587
# ----------------------------------------------------
# ------------------------------   Epoch: 04 --------------------------------
# Train Loss: 1.606, Test Loss: 0.799
# Train MSE: 1.652, Test MSE: 0.783
# Train MAE: 1.017, Test MAE: 0.687
# Train R²: 0.615, Test R²: 0.817
# ----------------------------------------------------
# ------------------------------   Epoch: 05 --------------------------------
# Train Loss: 0.823, Test Loss: 0.407
# Train MSE: 0.855, Test MSE: 0.421
# Train MAE: 0.729, Test MAE: 0.519
# Train R²: 0.801, Test R²: 0.902
# ----------------------------------------------------
# ------------------------------   Epoch: 06 --------------------------------
# Train Loss: 0.701, Test Loss: 0.216
# Train MSE: 0.697, Test MSE: 0.219
# Train MAE: 0.669, Test MAE: 0.373
# Train R²: 0.838, Test R²: 0.949
# ----------------------------------------------------
# ------------------------------   Epoch: 07 --------------------------------
# Train Loss: 0.390, Test Loss: 0.211
# Train MSE: 0.401, Test MSE: 0.214
# Train MAE: 0.495, Test MAE: 0.334
# Train R²: 0.906, Test R²: 0.950
# ----------------------------------------------------
# ------------------------------   Epoch: 08 --------------------------------
# Train Loss: 0.465, Test Loss: 0.176
# Train MSE: 0.475, Test MSE: 0.171
# Train MAE: 0.525, Test MAE: 0.318
# Train R²: 0.889, Test R²: 0.960
# ----------------------------------------------------
# ------------------------------   Epoch: 09 --------------------------------
# Train Loss: 0.401, Test Loss: 0.216
# Train MSE: 0.393, Test MSE: 0.216
# Train MAE: 0.492, Test MAE: 0.374
# Train R²: 0.908, Test R²: 0.950
# ----------------------------------------------------
# ------------------------------   Epoch: 10 --------------------------------
# Train Loss: 0.298, Test Loss: 0.167
# Train MSE: 0.307, Test MSE: 0.171
# Train MAE: 0.442, Test MAE: 0.313
# Train R²: 0.928, Test R²: 0.960
# ----------------------------------------------------
# ------------------------------   Epoch: 11 --------------------------------
# Train Loss: 0.432, Test Loss: 0.258
# Train MSE: 0.430, Test MSE: 0.261
# Train MAE: 0.504, Test MAE: 0.434
# Train R²: 0.900, Test R²: 0.939
# ----------------------------------------------------
# ------------------------------   Epoch: 12 --------------------------------
# Train Loss: 0.383, Test Loss: 0.113
# Train MSE: 0.394, Test MSE: 0.111
# Train MAE: 0.486, Test MAE: 0.264
# Train R²: 0.908, Test R²: 0.974
# ----------------------------------------------------
# ------------------------------   Epoch: 13 --------------------------------
# Train Loss: 0.336, Test Loss: 0.103
# Train MSE: 0.344, Test MSE: 0.105
# Train MAE: 0.464, Test MAE: 0.255
# Train R²: 0.920, Test R²: 0.975
# ----------------------------------------------------
# ------------------------------   Epoch: 14 --------------------------------
# Train Loss: 0.317, Test Loss: 0.081
# Train MSE: 0.317, Test MSE: 0.078
# Train MAE: 0.451, Test MAE: 0.220
# Train R²: 0.926, Test R²: 0.982
# ----------------------------------------------------
# ------------------------------   Epoch: 15 --------------------------------
# Train Loss: 0.311, Test Loss: 0.120
# Train MSE: 0.310, Test MSE: 0.115
# Train MAE: 0.443, Test MAE: 0.265
# Train R²: 0.928, Test R²: 0.973
# ----------------------------------------------------
# ------------------------------   Epoch: 16 --------------------------------
# Train Loss: 0.324, Test Loss: 0.080
# Train MSE: 0.333, Test MSE: 0.079
# Train MAE: 0.459, Test MAE: 0.213
# Train R²: 0.922, Test R²: 0.981
# ----------------------------------------------------
# ------------------------------   Epoch: 17 --------------------------------
# Train Loss: 0.223, Test Loss: 0.123
# Train MSE: 0.225, Test MSE: 0.113
# Train MAE: 0.376, Test MAE: 0.261
# Train R²: 0.947, Test R²: 0.974
# ----------------------------------------------------
# ------------------------------   Epoch: 18 --------------------------------
# Train Loss: 0.333, Test Loss: 0.081
# Train MSE: 0.330, Test MSE: 0.081
# Train MAE: 0.454, Test MAE: 0.234
# Train R²: 0.923, Test R²: 0.981
# ----------------------------------------------------
# ------------------------------   Epoch: 19 --------------------------------
# Train Loss: 0.319, Test Loss: 0.107
# Train MSE: 0.333, Test MSE: 0.107
# Train MAE: 0.453, Test MAE: 0.256
# Train R²: 0.922, Test R²: 0.975
# ----------------------------------------------------
# ------------------------------   Epoch: 20 --------------------------------
# Train Loss: 0.279, Test Loss: 0.070
# Train MSE: 0.284, Test MSE: 0.071
# Train MAE: 0.419, Test MAE: 0.192
# Train R²: 0.934, Test R²: 0.983
# ----------------------------------------------------
# ------------------------------   Epoch: 21 --------------------------------
# Train Loss: 0.283, Test Loss: 0.141
# Train MSE: 0.286, Test MSE: 0.142
# Train MAE: 0.405, Test MAE: 0.305
# Train R²: 0.933, Test R²: 0.967
# ----------------------------------------------------
# ------------------------------   Epoch: 22 --------------------------------
# Train Loss: 0.250, Test Loss: 0.085
# Train MSE: 0.257, Test MSE: 0.082
# Train MAE: 0.403, Test MAE: 0.240
# Train R²: 0.940, Test R²: 0.981
# ----------------------------------------------------
# ------------------------------   Epoch: 23 --------------------------------
# Train Loss: 0.264, Test Loss: 0.070
# Train MSE: 0.266, Test MSE: 0.071
# Train MAE: 0.427, Test MAE: 0.208
# Train R²: 0.938, Test R²: 0.983
# ----------------------------------------------------
# ------------------------------   Epoch: 24 --------------------------------
# Train Loss: 0.263, Test Loss: 0.090
# Train MSE: 0.261, Test MSE: 0.091
# Train MAE: 0.411, Test MAE: 0.243
# Train R²: 0.939, Test R²: 0.979
# ----------------------------------------------------
# ------------------------------   Epoch: 25 --------------------------------
# Train Loss: 0.265, Test Loss: 0.093
# Train MSE: 0.260, Test MSE: 0.093
# Train MAE: 0.399, Test MAE: 0.237
# Train R²: 0.939, Test R²: 0.978
# ----------------------------------------------------
# ------------------------------   Epoch: 26 --------------------------------
# Train Loss: 0.285, Test Loss: 0.196
# Train MSE: 0.278, Test MSE: 0.196
# Train MAE: 0.424, Test MAE: 0.378
# Train R²: 0.935, Test R²: 0.954
# ----------------------------------------------------
# ------------------------------   Epoch: 27 --------------------------------
# Train Loss: 0.331, Test Loss: 0.157
# Train MSE: 0.330, Test MSE: 0.156
# Train MAE: 0.477, Test MAE: 0.323
# Train R²: 0.923, Test R²: 0.964
# ----------------------------------------------------
# ------------------------------   Epoch: 28 --------------------------------
# Train Loss: 0.314, Test Loss: 0.147
# Train MSE: 0.310, Test MSE: 0.152
# Train MAE: 0.458, Test MAE: 0.330
# Train R²: 0.928, Test R²: 0.965
# ----------------------------------------------------
# ------------------------------   Epoch: 29 --------------------------------
# Train Loss: 0.281, Test Loss: 0.085
# Train MSE: 0.281, Test MSE: 0.084
# Train MAE: 0.431, Test MAE: 0.223
# Train R²: 0.934, Test R²: 0.980
# ----------------------------------------------------
# ------------------------------   Epoch: 30 --------------------------------
# Train Loss: 0.346, Test Loss: 0.071
# Train MSE: 0.322, Test MSE: 0.072
# Train MAE: 0.441, Test MAE: 0.211
# Train R²: 0.925, Test R²: 0.983
# ----------------------------------------------------
# ------------------------------   Epoch: 31 --------------------------------
# Train Loss: 0.316, Test Loss: 0.080
# Train MSE: 0.312, Test MSE: 0.081
# Train MAE: 0.457, Test MAE: 0.205
# Train R²: 0.927, Test R²: 0.981
# ----------------------------------------------------
# ------------------------------   Epoch: 32 --------------------------------
# Train Loss: 0.282, Test Loss: 0.086
# Train MSE: 0.281, Test MSE: 0.087
# Train MAE: 0.422, Test MAE: 0.233
# Train R²: 0.934, Test R²: 0.980
# ----------------------------------------------------
# ------------------------------   Epoch: 33 --------------------------------
# Train Loss: 0.210, Test Loss: 0.193
# Train MSE: 0.213, Test MSE: 0.196
# Train MAE: 0.375, Test MAE: 0.376
# Train R²: 0.950, Test R²: 0.954
# ----------------------------------------------------
# ------------------------------   Epoch: 34 --------------------------------
# Train Loss: 0.260, Test Loss: 0.103
# Train MSE: 0.266, Test MSE: 0.104
# Train MAE: 0.423, Test MAE: 0.269
# Train R²: 0.938, Test R²: 0.976
# ----------------------------------------------------
# ------------------------------   Epoch: 35 --------------------------------
# Train Loss: 0.300, Test Loss: 0.054
# Train MSE: 0.303, Test MSE: 0.052
# Train MAE: 0.444, Test MAE: 0.186
# Train R²: 0.929, Test R²: 0.988
# ----------------------------------------------------
# ----------------------------------------------------
# ----------------------------------------------------
#
# Training TextLSTM...
# ------------------------------   Epoch: 01 --------------------------------
# Train Loss: 19.292, Test Loss: 4.942
# Train MSE: 20.199, Test MSE: 5.160
# Train MAE: 3.877, Test MAE: 1.660
# Train R²: -3.712, Test R²: -0.204
# ----------------------------------------------------
# ------------------------------   Epoch: 02 --------------------------------
# Train Loss: 4.639, Test Loss: 3.822
# Train MSE: 4.643, Test MSE: 3.890
# Train MAE: 1.615, Test MAE: 1.501
# Train R²: -0.083, Test R²: 0.093
# ----------------------------------------------------
# ------------------------------   Epoch: 03 --------------------------------
# Train Loss: 3.871, Test Loss: 3.507
# Train MSE: 3.980, Test MSE: 3.526
# Train MAE: 1.534, Test MAE: 1.435
# Train R²: 0.072, Test R²: 0.177
# ----------------------------------------------------
# ------------------------------   Epoch: 04 --------------------------------
# Train Loss: 3.485, Test Loss: 2.571
# Train MSE: 3.628, Test MSE: 2.555
# Train MAE: 1.451, Test MAE: 1.173
# Train R²: 0.154, Test R²: 0.404
# ----------------------------------------------------
# ------------------------------   Epoch: 05 --------------------------------
# Train Loss: 4.793, Test Loss: 2.768
# Train MSE: 4.782, Test MSE: 2.681
# Train MAE: 1.727, Test MAE: 1.202
# Train R²: -0.115, Test R²: 0.375
# ----------------------------------------------------
# ------------------------------   Epoch: 06 --------------------------------
# Train Loss: 2.829, Test Loss: 2.213
# Train MSE: 2.858, Test MSE: 2.091
# Train MAE: 1.191, Test MAE: 1.002
# Train R²: 0.333, Test R²: 0.512
# ----------------------------------------------------
# ------------------------------   Epoch: 07 --------------------------------
# Train Loss: 2.088, Test Loss: 1.374
# Train MSE: 2.074, Test MSE: 1.330
# Train MAE: 1.059, Test MAE: 0.808
# Train R²: 0.516, Test R²: 0.690
# ----------------------------------------------------
# ------------------------------   Epoch: 08 --------------------------------
# Train Loss: 1.229, Test Loss: 0.664
# Train MSE: 1.259, Test MSE: 0.675
# Train MAE: 0.783, Test MAE: 0.577
# Train R²: 0.706, Test R²: 0.843
# ----------------------------------------------------
# ------------------------------   Epoch: 09 --------------------------------
# Train Loss: 0.912, Test Loss: 0.435
# Train MSE: 0.903, Test MSE: 0.423
# Train MAE: 0.678, Test MAE: 0.471
# Train R²: 0.789, Test R²: 0.901
# ----------------------------------------------------
# ------------------------------   Epoch: 10 --------------------------------
# Train Loss: 0.671, Test Loss: 0.240
# Train MSE: 0.670, Test MSE: 0.219
# Train MAE: 0.624, Test MAE: 0.336
# Train R²: 0.844, Test R²: 0.949
# ----------------------------------------------------
# ------------------------------   Epoch: 11 --------------------------------
# Train Loss: 0.375, Test Loss: 0.149
# Train MSE: 0.392, Test MSE: 0.146
# Train MAE: 0.505, Test MAE: 0.298
# Train R²: 0.909, Test R²: 0.966
# ----------------------------------------------------
# ------------------------------   Epoch: 12 --------------------------------
# Train Loss: 0.397, Test Loss: 0.113
# Train MSE: 0.411, Test MSE: 0.117
# Train MAE: 0.507, Test MAE: 0.269
# Train R²: 0.904, Test R²: 0.973
# ----------------------------------------------------
# ------------------------------   Epoch: 13 --------------------------------
# Train Loss: 0.275, Test Loss: 0.094
# Train MSE: 0.280, Test MSE: 0.092
# Train MAE: 0.430, Test MAE: 0.243
# Train R²: 0.935, Test R²: 0.979
# ----------------------------------------------------
# ------------------------------   Epoch: 14 --------------------------------
# Train Loss: 0.251, Test Loss: 0.100
# Train MSE: 0.255, Test MSE: 0.091
# Train MAE: 0.393, Test MAE: 0.224
# Train R²: 0.941, Test R²: 0.979
# ----------------------------------------------------
# ------------------------------   Epoch: 15 --------------------------------
# Train Loss: 0.337, Test Loss: 0.075
# Train MSE: 0.320, Test MSE: 0.077
# Train MAE: 0.445, Test MAE: 0.226
# Train R²: 0.925, Test R²: 0.982
# ----------------------------------------------------
# ------------------------------   Epoch: 16 --------------------------------
# Train Loss: 0.299, Test Loss: 0.099
# Train MSE: 0.286, Test MSE: 0.098
# Train MAE: 0.427, Test MAE: 0.236
# Train R²: 0.933, Test R²: 0.977
# ----------------------------------------------------
# ------------------------------   Epoch: 17 --------------------------------
# Train Loss: 0.288, Test Loss: 0.082
# Train MSE: 0.290, Test MSE: 0.083
# Train MAE: 0.425, Test MAE: 0.221
# Train R²: 0.932, Test R²: 0.981
# ----------------------------------------------------
# ------------------------------   Epoch: 18 --------------------------------
# Train Loss: 0.305, Test Loss: 0.062
# Train MSE: 0.312, Test MSE: 0.063
# Train MAE: 0.447, Test MAE: 0.192
# Train R²: 0.927, Test R²: 0.985
# ----------------------------------------------------
# ------------------------------   Epoch: 19 --------------------------------
# Train Loss: 0.314, Test Loss: 0.074
# Train MSE: 0.301, Test MSE: 0.074
# Train MAE: 0.440, Test MAE: 0.222
# Train R²: 0.930, Test R²: 0.983
# ----------------------------------------------------
# ------------------------------   Epoch: 20 --------------------------------
# Train Loss: 0.274, Test Loss: 0.076
# Train MSE: 0.276, Test MSE: 0.077
# Train MAE: 0.424, Test MAE: 0.223
# Train R²: 0.936, Test R²: 0.982
# ----------------------------------------------------
# ------------------------------   Epoch: 21 --------------------------------
# Train Loss: 0.296, Test Loss: 0.075
# Train MSE: 0.298, Test MSE: 0.076
# Train MAE: 0.431, Test MAE: 0.216
# Train R²: 0.931, Test R²: 0.982
# ----------------------------------------------------
# ------------------------------   Epoch: 22 --------------------------------
# Train Loss: 0.249, Test Loss: 0.079
# Train MSE: 0.247, Test MSE: 0.073
# Train MAE: 0.391, Test MAE: 0.206
# Train R²: 0.942, Test R²: 0.983
# ----------------------------------------------------
# ------------------------------   Epoch: 23 --------------------------------
# Train Loss: 0.285, Test Loss: 0.053
# Train MSE: 0.281, Test MSE: 0.055
# Train MAE: 0.424, Test MAE: 0.191
# Train R²: 0.934, Test R²: 0.987
# ----------------------------------------------------
# ------------------------------   Epoch: 24 --------------------------------
# Train Loss: 0.223, Test Loss: 0.044
# Train MSE: 0.221, Test MSE: 0.042
# Train MAE: 0.381, Test MAE: 0.156
# Train R²: 0.948, Test R²: 0.990
# ----------------------------------------------------
# ------------------------------   Epoch: 25 --------------------------------
# Train Loss: 0.248, Test Loss: 0.082
# Train MSE: 0.245, Test MSE: 0.083
# Train MAE: 0.405, Test MAE: 0.225
# Train R²: 0.943, Test R²: 0.981
# ----------------------------------------------------
# ------------------------------   Epoch: 26 --------------------------------
# Train Loss: 0.218, Test Loss: 0.070
# Train MSE: 0.220, Test MSE: 0.067
# Train MAE: 0.373, Test MAE: 0.201
# Train R²: 0.949, Test R²: 0.984
# ----------------------------------------------------
# ------------------------------   Epoch: 27 --------------------------------
# Train Loss: 0.232, Test Loss: 0.074
# Train MSE: 0.232, Test MSE: 0.074
# Train MAE: 0.385, Test MAE: 0.217
# Train R²: 0.946, Test R²: 0.983
# ----------------------------------------------------
# ------------------------------   Epoch: 28 --------------------------------
# Train Loss: 0.234, Test Loss: 0.053
# Train MSE: 0.241, Test MSE: 0.051
# Train MAE: 0.397, Test MAE: 0.174
# Train R²: 0.944, Test R²: 0.988
# ----------------------------------------------------
# ------------------------------   Epoch: 29 --------------------------------
# Train Loss: 0.171, Test Loss: 0.072
# Train MSE: 0.168, Test MSE: 0.070
# Train MAE: 0.325, Test MAE: 0.208
# Train R²: 0.961, Test R²: 0.984
# ----------------------------------------------------
# ------------------------------   Epoch: 30 --------------------------------
# Train Loss: 0.302, Test Loss: 0.049
# Train MSE: 0.309, Test MSE: 0.049
# Train MAE: 0.456, Test MAE: 0.172
# Train R²: 0.928, Test R²: 0.989
# ----------------------------------------------------
# ------------------------------   Epoch: 31 --------------------------------
# Train Loss: 0.224, Test Loss: 0.077
# Train MSE: 0.224, Test MSE: 0.079
# Train MAE: 0.401, Test MAE: 0.234
# Train R²: 0.948, Test R²: 0.982
# ----------------------------------------------------
# ------------------------------   Epoch: 32 --------------------------------
# Train Loss: 0.249, Test Loss: 0.059
# Train MSE: 0.255, Test MSE: 0.058
# Train MAE: 0.412, Test MAE: 0.192
# Train R²: 0.941, Test R²: 0.987
# ----------------------------------------------------
# ------------------------------   Epoch: 33 --------------------------------
# Train Loss: 0.225, Test Loss: 0.056
# Train MSE: 0.233, Test MSE: 0.057
# Train MAE: 0.388, Test MAE: 0.187
# Train R²: 0.946, Test R²: 0.987
# ----------------------------------------------------
# ------------------------------   Epoch: 34 --------------------------------
# Train Loss: 0.197, Test Loss: 0.066
# Train MSE: 0.202, Test MSE: 0.068
# Train MAE: 0.364, Test MAE: 0.216
# Train R²: 0.953, Test R²: 0.984
# ----------------------------------------------------
# ------------------------------   Epoch: 35 --------------------------------
# Train Loss: 0.259, Test Loss: 0.043
# Train MSE: 0.266, Test MSE: 0.042
# Train MAE: 0.418, Test MAE: 0.172
# Train R²: 0.938, Test R²: 0.990
# ----------------------------------------------------

# %% [markdown]
# #### Among the three architectures, TextLSTM consistently showed the best performance, achieving the lowest losses and highest R² scores across epochs. TextGRU followed closely behind, while TextRNN generally lagged behind the other two in terms of performance.
